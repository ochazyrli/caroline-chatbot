# %% [markdown]
# # I. Import Library

# %%
import pandas as pd
import numpy as np
import string
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity, linear_kernel
from sklearn.compose import make_column_transformer
import pickle

# %% [markdown]
# # II. Data Loading and Preprocessing

# %%
df = pd.read_csv('sephora_website_dataset.csv')

# %%
df.head(2)
# Out:
#         id           brand   category                            name  \
# 0  2218774  Acqua Di Parma  Fragrance  Blu Mediterraneo MINIATURE Set
# 1  2044816  Acqua Di Parma    Cologne                         Colonia
#
#              size  rating  number_of_reviews  love  price  value_price  ...  \
# 0  5 x 0.16oz/5mL     4.0                  4  3002   66.0         75.0  ...
# 1   0.7 oz/ 20 mL     4.5                 76  2700   66.0         66.0  ...
#
#   MarketingFlags  MarketingFlags_content  \
# 0           True             online only
# 1           True             online only
#
#                                              options  \
# 0                                         no options
# 1   - 0.7 oz/ 20 mL  Spray  - 1.7 oz/ 50 mL Eau d...
#
#                                              details  \
# 0  This enchanting set comes in a specially handc...
# 1  An elegant timeless scent filled with a fresh-...
#
#                                           how_to_use  \
# 0  Suggested Usage:-Fragrance is intensified by t...
# 1                                    no instructions
#
#                                          ingredients online_only  exclusive  \
# 0  Arancia di Capri Eau de Toilette: Alcohol Dena...           1          0
# 1                                            unknown           1          0
#
#    limited_edition  limited_time_offer
# 0                0                   0
# 1                0                   0
#
# [2 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9168 entries, 0 to 9167
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      9168 non-null   int64
#  1   brand                   9168 non-null   object
#  2   category                9168 non-null   object
#  3   name                    9168 non-null   object
#  4   size                    9168 non-null   object
#  5   rating                  9168 non-null   float64
#  6   number_of_reviews       9168 non-null   int64
#  7   love                    9168 non-null   int64
#  8   price                   9168 non-null   float64
#  9   value_price             9168 non-null   float64
#  10  URL                     9168 non-null   object
#  11  MarketingFlags          9168 non-null   bool
#  12  MarketingFlags_content  9168 non-null   object
#  13  options                 9168 non-null   object
#  14  details                 9168 non-null   object
#  15  how_to_use              9168 non-null   object
#  16  ingredients             9168 non-null   object
#  17  online_only             9168 non-null   int64
#  18  exclusive               9168 non-null   int64
#  19  limited_edition         9168 non-null   int64
#  20  limited_time_offer      9168 non-null   int64
# dtypes: bool(1), float64(3), int64(7), object(10)
# memory usage: 1.4+ MB

# %% [markdown]
# Tidak ditemukan missing value pada data

# %%
df.category.value_counts().nlargest(15)
# Out:
# Perfume                      665
# Moisturizers                 451
# Face Serums                  384
# Value & Gift Sets            378
# Face Wash & Cleansers        247
# Face Masks                   230
# Rollerballs & Travel Size    228
# Hair Styling Products        224
# Eye Palettes                 202
# Lipstick                     191
# Eye Creams & Treatments      191
# Shampoo                      186
# Face Brushes                 183
# Highlighter                  169
# Foundation                   163
# Name: category, dtype: int64

# %% [markdown]
# Hanya dipilih category yang memang mempunyai banyak barang yaitu Perfume, Moisturizers, Face Serums, Face Wash & Cleansers dan Face Masks

# %%
data = df.query("category == ['Perfume', 'Moisturizers', 'Face Serums', 'Face Wash & Cleansers', 'Face Masks']")
data
# Out:
#            id               brand               category  \
# 2     1417567      Acqua Di Parma                Perfume
# 3     1417617      Acqua Di Parma                Perfume
# 5     1417609      Acqua Di Parma                Perfume
# 6     1638832      Acqua Di Parma                Perfume
# 9     2221596      Acqua Di Parma                Perfume
# ...       ...                 ...                    ...
# 9131  2208494  SEPHORA COLLECTION             Face Masks
# 9141  2210284  SEPHORA COLLECTION             Face Masks
# 9148  1617489  SEPHORA COLLECTION             Face Masks
# 9152  1662410  SEPHORA COLLECTION  Face Wash & Cleansers
# 9163  2208502  SEPHORA COLLECTION             Face Masks
#
#                                   name            size  rating  \
# 2                     Arancia di Capri    5 oz/ 148 mL     4.5
# 3                     Mirto di Panarea   2.5 oz/ 74 mL     4.5
# 5                       Fico di Amalfi    5 oz/ 148 mL     4.5
# 6                          Rosa Nobile  3.4 oz/ 101 mL     4.5
# 9                Rosa Nobile Hair Mist      1.7oz/50mL     3.0
# ...                                ...             ...     ...
# 9131                     The Blue Mask         no size     3.5
# 9141                   The Golden Mask         no size     4.0
# 9148  Mud Mask Purifying & Mattifying          no size     4.5
# 9152             Supreme Cleansing Oil  6.4 oz/ 190 mL     4.5
# 9163                The Rose Gold Mask         no size     2.0
#
#       number_of_reviews   love  price  value_price  ... MarketingFlags  \
# 2                    26   2600  180.0        180.0  ...           True
# 3                    23   2900  120.0        120.0  ...           True
# 5                    79   2600  180.0        180.0  ...           True
# 6                    79   5000  210.0        210.0  ...           True
# 9                     5   2100   58.0         58.0  ...           True
# ...                 ...    ...    ...          ...  ...            ...
# 9131                 20   4100    6.0          6.0  ...           True
# 9141                 22   5000    6.0          6.0  ...           True
# 9148               1000  48200   20.0         20.0  ...           True
# 9152                357  15800   15.0         15.0  ...           True
# 9163                 15   6200    6.0          6.0  ...           True
#
#            MarketingFlags_content  \
# 2                     online only
# 3                     online only
# 5                     online only
# 6                     online only
# 9         exclusive · online only
# ...                           ...
# 9131  limited edition · exclusive
# 9141  limited edition · exclusive
# 9148                    exclusive
# 9152                    exclusive
# 9163  limited edition · exclusive
#
#                                                 options  \
# 2      - 1oz/30mL Eau de Toilette  - 2.5 oz/ 74 mL E...
# 3      - 1 oz/ 30 mL Eau de Toilette Spray - 2.5 oz/...
# 5      - 1oz/30mL Eau de Toilette  - 2.5 oz/ 74 mL E...
# 6      - 0.7 oz, 20 mL Eau de Parfum Spray - 1.7 oz/...
# 9                              - 1.7oz/50mL  Hair Mist
# ...                                                 ...
# 9131                                         no options
# 9141                                         no options
# 9148                                         no options
# 9152                                         no options
# 9163                                         no options
#
#                                                 details  \
# 2     Fragrance Family: Fresh Scent Type: Fresh Citr...
# 3     Panarea near Sicily is an an island suspended ...
# 5     Fragrance Family: Floral Scent Type: Fruity Fl...
# 6     Fragrance Family: Floral\r\n\r\nScent Type: Cl...
# 9     Fragrance Family: Floral\r\n\r\nScent Type: Cl...
# ...                                                 ...
# 9131  What it is: A limited-edition- ultra-toning fo...
# 9141  What it is: A limited-edition- ultra-moisturiz...
# 9148  What it is: \r\nA mud mask featuring zinc and ...
# 9152  What it is:\r\nA cleansing oil with the effect...
# 9163  What it is: A limited-edition- nurturing and h...
#
#                                              how_to_use  \
# 2                                       no instructions
# 3                                       no instructions
# 5                                       no instructions
# 6                                       no instructions
# 9     Suggested Usage:-Spray over your hair to leave...
# ...                                                 ...
# 9131  Suggested Usage:-Unfold the mask.-Apply the ma...
# 9141  Suggested Usage:-Unfold the mask.-Apply the ma...
# 9148  Suggested Usage:-Use one to two times per week...
# 9152  Suggested Usage:\r\n-Dispense one dose from th...
# 9163  Suggested Usage:-Unfold the mask.-Apply the ma...
#
#                                             ingredients online_only  \
# 2     Alcohol Denat.- Water- Fragrance- Limonene- Li...           1
# 3                                               unknown           1
# 5                                               unknown           1
# 6                                               unknown           1
# 9                                               unknown           1
# ...                                                 ...         ...
# 9131  -Sapphire Extract: Smooths tired-looking skin....           0
# 9141  -Honey Extract: Known for its moisturizing pow...           0
# 9148   -Zinc and Copper: Purify.\r\n-White Clay: Sof...           0
# 9152   -Cottonseed Oil: Nourishes and provides smoot...           0
# 9163  -Rose Quartz Extract: Hydrates dry skin.  Aqua...           0
#
#       exclusive  limited_edition  limited_time_offer
# 2             0                0                   0
# 3             0                0                   0
# 5             0                0                   0
# 6             0                0                   0
# 9             1                0                   0
# ...         ...              ...                 ...
# 9131          1                1                   0
# 9141          1                1                   0
# 9148          1                0                   0
# 9152          1                0                   0
# 9163          1                1                   0
#
# [1977 rows x 21 columns]

# %%
data.reset_index(drop=True, inplace=True)
data
# Out:
#            id               brand               category  \
# 0     1417567      Acqua Di Parma                Perfume
# 1     1417617      Acqua Di Parma                Perfume
# 2     1417609      Acqua Di Parma                Perfume
# 3     1638832      Acqua Di Parma                Perfume
# 4     2221596      Acqua Di Parma                Perfume
# ...       ...                 ...                    ...
# 1972  2208494  SEPHORA COLLECTION             Face Masks
# 1973  2210284  SEPHORA COLLECTION             Face Masks
# 1974  1617489  SEPHORA COLLECTION             Face Masks
# 1975  1662410  SEPHORA COLLECTION  Face Wash & Cleansers
# 1976  2208502  SEPHORA COLLECTION             Face Masks
#
#                                   name            size  rating  \
# 0                     Arancia di Capri    5 oz/ 148 mL     4.5
# 1                     Mirto di Panarea   2.5 oz/ 74 mL     4.5
# 2                       Fico di Amalfi    5 oz/ 148 mL     4.5
# 3                          Rosa Nobile  3.4 oz/ 101 mL     4.5
# 4                Rosa Nobile Hair Mist      1.7oz/50mL     3.0
# ...                                ...             ...     ...
# 1972                     The Blue Mask         no size     3.5
# 1973                   The Golden Mask         no size     4.0
# 1974  Mud Mask Purifying & Mattifying          no size     4.5
# 1975             Supreme Cleansing Oil  6.4 oz/ 190 mL     4.5
# 1976                The Rose Gold Mask         no size     2.0
#
#       number_of_reviews   love  price  value_price  ... MarketingFlags  \
# 0                    26   2600  180.0        180.0  ...           True
# 1                    23   2900  120.0        120.0  ...           True
# 2                    79   2600  180.0        180.0  ...           True
# 3                    79   5000  210.0        210.0  ...           True
# 4                     5   2100   58.0         58.0  ...           True
# ...                 ...    ...    ...          ...  ...            ...
# 1972                 20   4100    6.0          6.0  ...           True
# 1973                 22   5000    6.0          6.0  ...           True
# 1974               1000  48200   20.0         20.0  ...           True
# 1975                357  15800   15.0         15.0  ...           True
# 1976                 15   6200    6.0          6.0  ...           True
#
#            MarketingFlags_content  \
# 0                     online only
# 1                     online only
# 2                     online only
# 3                     online only
# 4         exclusive · online only
# ...                           ...
# 1972  limited edition · exclusive
# 1973  limited edition · exclusive
# 1974                    exclusive
# 1975                    exclusive
# 1976  limited edition · exclusive
#
#                                                 options  \
# 0      - 1oz/30mL Eau de Toilette  - 2.5 oz/ 74 mL E...
# 1      - 1 oz/ 30 mL Eau de Toilette Spray - 2.5 oz/...
# 2      - 1oz/30mL Eau de Toilette  - 2.5 oz/ 74 mL E...
# 3      - 0.7 oz, 20 mL Eau de Parfum Spray - 1.7 oz/...
# 4                              - 1.7oz/50mL  Hair Mist
# ...                                                 ...
# 1972                                         no options
# 1973                                         no options
# 1974                                         no options
# 1975                                         no options
# 1976                                         no options
#
#                                                 details  \
# 0     Fragrance Family: Fresh Scent Type: Fresh Citr...
# 1     Panarea near Sicily is an an island suspended ...
# 2     Fragrance Family: Floral Scent Type: Fruity Fl...
# 3     Fragrance Family: Floral\r\n\r\nScent Type: Cl...
# 4     Fragrance Family: Floral\r\n\r\nScent Type: Cl...
# ...                                                 ...
# 1972  What it is: A limited-edition- ultra-toning fo...
# 1973  What it is: A limited-edition- ultra-moisturiz...
# 1974  What it is: \r\nA mud mask featuring zinc and ...
# 1975  What it is:\r\nA cleansing oil with the effect...
# 1976  What it is: A limited-edition- nurturing and h...
#
#                                              how_to_use  \
# 0                                       no instructions
# 1                                       no instructions
# 2                                       no instructions
# 3                                       no instructions
# 4     Suggested Usage:-Spray over your hair to leave...
# ...                                                 ...
# 1972  Suggested Usage:-Unfold the mask.-Apply the ma...
# 1973  Suggested Usage:-Unfold the mask.-Apply the ma...
# 1974  Suggested Usage:-Use one to two times per week...
# 1975  Suggested Usage:\r\n-Dispense one dose from th...
# 1976  Suggested Usage:-Unfold the mask.-Apply the ma...
#
#                                             ingredients online_only  \
# 0     Alcohol Denat.- Water- Fragrance- Limonene- Li...           1
# 1                                               unknown           1
# 2                                               unknown           1
# 3                                               unknown           1
# 4                                               unknown           1
# ...                                                 ...         ...
# 1972  -Sapphire Extract: Smooths tired-looking skin....           0
# 1973  -Honey Extract: Known for its moisturizing pow...           0
# 1974   -Zinc and Copper: Purify.\r\n-White Clay: Sof...           0
# 1975   -Cottonseed Oil: Nourishes and provides smoot...           0
# 1976  -Rose Quartz Extract: Hydrates dry skin.  Aqua...           0
#
#       exclusive  limited_edition  limited_time_offer
# 0             0                0                   0
# 1             0                0                   0
# 2             0                0                   0
# 3             0                0                   0
# 4             1                0                   0
# ...         ...              ...                 ...
# 1972          1                1                   0
# 1973          1                1                   0
# 1974          1                0                   0
# 1975          1                0                   0
# 1976          1                1                   0
#
# [1977 rows x 21 columns]

# %% [markdown]
# # III. Recommendation Using Cosine Similarity

# %%
tf = TfidfVectorizer(analyzer='word', stop_words='english')
ct = make_column_transformer((tf, 'ingredients'), (tf, 'category'))
matrix = ct.fit_transform(data)

# %%
cos_sim = cosine_similarity(matrix, matrix)

# %%
cos_sim[0]
# Out:
# array([1.        , 0.5       , 0.5       , ..., 0.00210024, 0.00631874,
#        0.00258247])

# %%
data = data.reset_index()
names = data['name']
indices = pd.Series(data.index, index=data['name'])

# %%
def get_recommendations(name):
    idx = indices[name]
    sim_scores = list(enumerate(cos_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:31]
    name_indices = [i[0] for i in sim_scores]
    return names.iloc[name_indices][0:5]

# %%
get_recommendations('Rose Cleansing Foam')
# Out:
# 741     Soy Makeup Removing Face Wash
# 762           Soy Face Cleansing Milk
# 1061            Ultra Facial Cleanser
# 167               Lathering Tube Soap
# 67           Treatment Cleansing Foam
# Name: name, dtype: object

# %%
pickle.dump(cos_sim, open('cos_sim.pkl', 'wb'))

# %% [markdown]
# # IV. Simple Recommendation by Filtering

# %%
df_new = data[['brand', 'name', 'category', 'rating', 'love']]
df_new
# Out:
#                    brand                              name  \
# 0         Acqua Di Parma                  Arancia di Capri
# 1         Acqua Di Parma                  Mirto di Panarea
# 2         Acqua Di Parma                    Fico di Amalfi
# 3         Acqua Di Parma                       Rosa Nobile
# 4         Acqua Di Parma             Rosa Nobile Hair Mist
# ...                  ...                               ...
# 1972  SEPHORA COLLECTION                     The Blue Mask
# 1973  SEPHORA COLLECTION                   The Golden Mask
# 1974  SEPHORA COLLECTION  Mud Mask Purifying & Mattifying
# 1975  SEPHORA COLLECTION             Supreme Cleansing Oil
# 1976  SEPHORA COLLECTION                The Rose Gold Mask
#
#                    category  rating   love
# 0                   Perfume     4.5   2600
# 1                   Perfume     4.5   2900
# 2                   Perfume     4.5   2600
# 3                   Perfume     4.5   5000
# 4                   Perfume     3.0   2100
# ...                     ...     ...    ...
# 1972             Face Masks     3.5   4100
# 1973             Face Masks     4.0   5000
# 1974             Face Masks     4.5  48200
# 1975  Face Wash & Cleansers     4.5  15800
# 1976             Face Masks     2.0   6200
#
# [1977 rows x 5 columns]

# %%
df_new['rating'].value_counts()
# Out:
# 4.5    934
# 4.0    646
# 5.0    162
# 3.5    149
# 3.0     40
# 0.0     30
# 2.5      8
# 2.0      5
# 1.0      3
# Name: rating, dtype: int64

# %%
df_new['category'].value_counts()
# Out:
# Perfume                  665
# Moisturizers             451
# Face Serums              384
# Face Wash & Cleansers    247
# Face Masks               230
# Name: category, dtype: int64

# %%
df_new['love'].groupby(df_new['category']).describe()
# Out:
#                        count          mean           std  min     25%     50%  \
# category
# Face Masks             230.0  21469.904348  36835.692508  0.0  2425.0  7550.0
# Face Serums            384.0  15602.101562  30937.864606  0.0  1900.0  5250.0
# Face Wash & Cleansers  247.0  14975.421053  27317.720434  0.0  2500.0  5100.0
# Moisturizers           451.0  12365.017738  25056.247135  0.0  1700.0  4300.0
# Perfume                665.0   6953.996992  12732.625647  0.0  1300.0  3100.0
#
#                            75%       max
# category
# Face Masks             23225.0  256200.0
# Face Serums            13850.0  225500.0
# Face Wash & Cleansers  14200.0  195000.0
# Moisturizers           10250.0  233700.0
# Perfume                 7600.0  144700.0

# %%
def get_recommendations_new(input):
    new_rec = data.loc[(data['category'] == input) & (data['rating'] == 4.5) & (data['love'] >= 80000)]
    rec = new_rec['name'].to_numpy()
    return rec[0:5]

# %%
get_recommendations_new('Face Wash & Cleansers')
# Out:
# array(['MakeUp-BreakUp Cool Cleansing Oil',
#        'Detoxifying Black Charcoal Cleanser',
#        'Take The Day Off Cleansing Balm',
#        'Green Clean Makeup Removing Cleansing Balm',
#        'Pure Skin Face Cleanser'], dtype=object)

# %%
get_recommendations_new('Face Masks')
# Out:
# array(['T.L.C. Sukari Babyfacial™  25% AHA + 2% BHA Mask',
#        'Umbrian Clay Pore Purifying Face Mask',
#        'THIRSTYMUD™ Hydrating Treatment Mask',
#        'Blue Tansy Fruit Enzyme Resurfacing Clarity Mask',
#        'Water Sleeping Mask'], dtype=object)

# %%
get_recommendations_new('Face Serums')
# Out:
# array(['T.L.C. Framboos™ Glycolic Resurfacing Night Serum',
#        'B-Hydra™ Intensive Hydration Serum', 'Lactic Acid 10% + HA',
#        'Granactive Retinoid* 2% Emulsion',
#        'Violet-C Brightening Serum 20% Vitamin C + 10% AHA'], dtype=object)

# %%
get_recommendations_new('Moisturizers')
# Out:
# array(['The True Cream Moisturizing Bomb', 'The True Cream Aqua Bomb',
#        'Vitamin Enriched Face Base Priming Moisturizer',
#        'Dramatically Different Moisturizing Gel',
#        'Ultra Repair® Cream Intense Hydration'], dtype=object)

# %%
get_recommendations_new('Perfume')
# Out:
# array(['COCO MADEMOISELLE Eau de Parfum', 'Chloé Eau de Parfum', 'Daisy',
#        'Bright Crystal', 'Flowerbomb'], dtype=object)

# %% [markdown]
# # V. Data Export to CSV

# %%
data.to_csv('data_clean.csv', index=False)
